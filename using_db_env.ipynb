# %%
# auto reload when changes are made in this directory
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Web scraping + Inserting into database

# %%
from data_processing import *

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 160)
pd.set_option('display.max_rows', None)
st = "IL"
reg = "Franklin Park"
table_number = 1
municode = "https://library.municode.com/il/franklin_park/codes/code_of_ordinances?nodeId=CO_TIT9ZOOR_CH11OREPALO_9-11-5REOREVEPASP"

# test_connection()
# create_csv_url("IL", "Winnebago County")
# create_csv_url(st, reg, municode, table_number)
read_database()
# Out:
# Connecting to database...
# -----------------------------------------------------------
#             Enter number for command:
#                 (1) Show all
#                 (2) Filter
#                 (3) Count
#                 (4) Exit
#                 >>> 1
# Fetching all entries.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3288, in Engine.raw_connection(self)
#    3267 """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269 The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287 """
# -> 3288 return self.pool.connect()
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:1268, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1267 if not fairy:
# -> 1268     fairy = _ConnectionRecord.checkout(pool)
#    1270     if threadconns is not None:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     168 with util.safe_reraise():
# --> 169     self._dec_overflow()
#     170 raise
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:903, in _ConnectionRecord.__connect(self)
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: could not connect to server: Operation timed out
# 	Is the server running on host "db.ivzidqccueblykefgvbg.supabase.co" (13.57.242.232) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 12
#       7 municode = "https://library.municode.com/il/franklin_park/codes/code_of_ordinances?nodeId=CO_TIT9ZOOR_CH11OREPALO_9-11-5REOREVEPASP"
#       9 # test_connection()
#      10 # create_csv_url("IL", "Winnebago County")
#      11 # create_csv_url(st, reg, municode, table_number)
# ---> 12 read_database()
#
# File ~/Desktop/College/UCLA/PSYCH 195B/Parking Reform Network/parking-requirement-database/database_functions.py:123, in read_database()
#     121 print("Fetching all entries.")
#     122 # print(f"Query: {statement}")
# --> 123 result = session.scalars(statement).all()
#     124 #print(result)
#     125 #result = [r[0] for r in result]
#     126 print(tabulate(result, headers=["state", "region", "use", "raw"], tablefmt='grid',
#     127                maxcolwidths=[None, None, 20, 20]))
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/orm/session.py:2343, in Session.scalars(self, statement, params, execution_options, bind_arguments, **kw)
#    2314 def scalars(
#    2315     self,
#    2316     statement: Executable,
#    (...)
#    2321     **kw: Any,
#    2322 ) -> ScalarResult[Any]:
#    2323     """Execute a statement and return the results as scalars.
#    2324
#    2325     Usage and parameters are the same as that of
#    (...)
#    2340
#    2341     """
# -> 2343     return self._execute_internal(
#    2344         statement,
#    2345         params=params,
#    2346         execution_options=execution_options,
#    2347         bind_arguments=bind_arguments,
#    2348         _scalar_result=False,  # mypy appreciates this
#    2349         **kw,
#    2350     ).scalars()
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/orm/session.py:2116, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2102     (
#    2103         statement,
#    2104         execution_options,
#    (...)
#    2111         False,
#    2112     )
#    2114 bind = self.get_bind(**bind_arguments)
# -> 2116 conn = self._connection_for_bind(bind)
#    2118 if _scalar_result and not compile_state_cls:
#    2119     if TYPE_CHECKING:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/orm/session.py:1983, in Session._connection_for_bind(self, engine, execution_options, **kw)
#    1981 if trans is None:
#    1982     trans = self._autobegin_t()
# -> 1983 return trans._connection_for_bind(engine, execution_options)
#
# File <string>:2, in _connection_for_bind(self, bind, execution_options)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/orm/session.py:1110, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#    1105             raise sa_exc.InvalidRequestError(
#    1106                 "Session already has a Connection associated for the "
#    1107                 "given Connection's Engine"
#    1108             )
#    1109     else:
# -> 1110         conn = bind.connect()
#    1111         local_connect = True
#    1113 try:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3264, in Engine.connect(self)
#    3241 def connect(self) -> Connection:
#    3242     """Return a new :class:`_engine.Connection` object.
#    3243
#    3244     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3261
#    3262     """
# -> 3264     return self._connection_cls(self)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2426, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2424 elif should_wrap:
#    2425     assert sqlalchemy_exception is not None
# -> 2426     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2427 else:
#    2428     assert exc_info[1] is not None
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3288, in Engine.raw_connection(self)
#    3266 def raw_connection(self) -> PoolProxiedConnection:
#    3267     """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269     The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287     """
# -> 3288     return self.pool.connect()
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:1268, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1259 @classmethod
#    1260 def _checkout(
#    1261     cls,
#    (...)
#    1264     fairy: Optional[_ConnectionFairy] = None,
#    1265 ) -> _ConnectionFairy:
#    1267     if not fairy:
# -> 1268         fairy = _ConnectionRecord.checkout(pool)
#    1270         if threadconns is not None:
#    1271             threadconns.current = weakref.ref(fairy)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:169, in QueuePool._do_get(self)
#     167     except:
#     168         with util.safe_reraise():
# --> 169             self._dec_overflow()
#     170         raise
#     171 else:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:903, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#     907     if pool.dispatch.first_connect:
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/pool/base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/test_env/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Operation timed out
# 	Is the server running on host "db.ivzidqccueblykefgvbg.supabase.co" (13.57.242.232) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Scraping pdfs

# %%
from scraper_functions import *

# %%
read_pdf(r'pdfs/concord_parking.pdf', [1,2,3])
# if errors related to ghostscript occurs, try "!apt install ghostscript"
# Out:
# Total tables extracted: 3
#                                                     0                                                  1                                                  2
# 0                                            Land Use                                Min. Vehicle Spaces                                Max. Vehicle Spaces
# 1                                         Residential
# 2   Single Family, detached (includes\nmanufacture...                                       2 per parcel                                                n/a
# 3                          Duplex (Two units per lot)                                         2 per unit                                                n/a
# 4   Multi-Family (3 or more units) and\nattached S...                                       1.5 per unit                                       2.5 per unit
# 5                                 Accessory Dwellings                                         1 per unit                                                n/a
# 6                                    Family Care Home                                       2 per parcel                                                n/a
# 7                             Institutional and Civic
# 8                          Auditorium/Public Assembly    1 per 6 seats or 1 per 50 sf\nGFA (if no seats)    1 per 4 seats or 1 per 30\nsf GFA (if no seats)
# 9               Botanical Garden and Nature Preserves                                                n/a                          1 per 125 sf GFA of bldg.
# 10                                         Campground  1 per 6 camp sites, plus4 per\nlaundry & showe...                                                n/a
# 11                                  Child Care Center                                   1 per 375 sf GFA                                 1.5 per 375 sf GFA
# 12          Civic, Social and Fraternal Organizations                                   1 per 250 sf GFA                                   1 per 200 sf GFA
# 13                       Emergency Service Facilities  1 per employee + 1 per 3\nvolunteer personnel ...                                                n/a
# 14                                        Golf Course                                         4 per hole                                         6 per hole
# 15                                 Golf Driving Range                                       1 per 2 tees                                          1 per tee
# 16                              Governments Buildings                                   1 per 300 sf GFA                                   1 per 125 sf GFA
# 17                                           Hospital                                   1 per 400 sf GFA                                   1 per 100 sf GFA
# 18                          Museums and Art Galleries                                 1 per 1,000 sf GFA                               1.5 per 1,000 sf GFA
# 19                                       Park, public                                      1 per 4 seats                                         1 per seat
# 20                             Religious Institutions                                      1 per 8 seats                                    1 per 1.5 seats
# 21       Residential Care Facilities and Group\nHomes                                       0.3 per room                                         1 per room
# 22  Schools – Business, Trade and/or other\nVocati...                                   1 per 200 sf GFA                                   1 per 150 sf GFA
# 23                 Schools – Elementary and Secondary                                    1 per classroom                                    2 per classroom
# 24                    Schools – University or College                                   1 per 4 students                                   1 per 2 students
# 25                       All other Institutional Uses                          1 per 300 sf GFA of bldg.                          1 per 125 sf GFA of bldg.
# 26              Professional Office/Business Services
# 27                                   Offices, General                                 1 per 1,000 sf GFA                                   1 per 200 sf GFA
# 28                         Banks (with drive-through)  1 per 300 sf GFA, plus\nsufficient stacking sp...  1 per 150 sf GFA, plus\nsufficient stacking sp...
# 29           Banks (without drive-through facilities)                                   1 per 250 sf GFA                                   1 per 140 sf GFA
# 30                          Funeral Home and Services                                      1 per 4 seats                                      1 per 2 seats
# 31             Personal Services (Dry Cleaners, etc.)                                   1 per 500 sf GFA                                   1 per 215 sf GFA
# 32          Personal Care Services (Hair, skin, etc.)                                   1 per 200 sf GFA                                   1 per 100 sf GFA
# 33  All other Professional Office/Business\nServic...                                   1 per 300 sf GFA                                   1 per 150 sf GFA
# 34                                       Retail Trade
# 35                                   Amusement Arcade  1 per game table, video game\nor other amuseme...                                                n/a
# 36                                     Amusement Park           1 per 600 sf of outdoor\nrecreation area           1 per 500 sf of outdoor\nrecreation area
# 37        Automobile Sales, New and Used (see §\n5.6)  1 per 375 sf GFA of sales\narea, plus 1 per em...  1.5 per 375 sf GFA of sales\narea, plus 1 per ...
