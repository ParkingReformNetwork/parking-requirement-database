# %%
# auto reload when changes are made in this directory
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Web scraping + Inserting into database

# %%
from data_processing import *

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 160)
pd.set_option('display.max_rows', None)
st = "IL"
reg = "Franklin Park"
table_number = 1
municode = "https://library.municode.com/il/franklin_park/codes/code_of_ordinances?nodeId=CO_TIT9ZOOR_CH11OREPALO_9-11-5REOREVEPASP"

test_connection()
#create_csv_url("IL", "Winnebago County")
# create_csv_url(st, reg, municode, table_number)
# read_database()
# Out:
# Testing connection to database.
# Attempting querying database.
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\db_env\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\envs\db_env\Lib\site-packages\sqlalchemy\engine\base.py:3288, in Engine.raw_connection(self)
#    3267 """Return a "raw" DBAPI connection from the connection pool.
#    3268
#    3269 The returned object is a proxied version of the DBAPI
#    (...)
#    3286
#    3287 """
# -> 3288 return self.pool.connect()
#
# File ~\anaconda3\envs\db_env\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
# ...

# %%
# Scraping pdfs

# %%
from scraper_functions import *

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 140)
pd.set_option('display.max_rows', None)

read_pdf(r'pdfs\concord_parking.pdf', [1,2,3])
# if errors related to ghostscript occurs, try "!apt install ghostscript"
# Out:
# Total tables extracted: 3
#                                                     0                                                  1  \
# 0                                            Land Use                                Min. Vehicle Spaces
# 1                                         Residential
# 2   Single Family, detached (includes manufactured...                                       2 per parcel
# 3                          Duplex (Two units per lot)                                         2 per unit
# 4   Multi-Family (3 or more units) and attached Si...                                       1.5 per unit
# 5                                 Accessory Dwellings                                         1 per unit
# 6                                    Family Care Home                                       2 per parcel
# 7                             Institutional and Civic
# 8                          Auditorium/Public Assembly     1 per 6 seats or 1 per 50 sf GFA (if no seats)
# ...
