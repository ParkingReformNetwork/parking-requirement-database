# %%
# !scrapy crawl munispider
# Out:
# 2023-05-17 13:22:30 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: web_crawling)
# 2023-05-17 13:22:30 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.10.3, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.10.0, Python 3.11.3 | packaged by Anaconda, Inc. | (main, Apr 19 2023, 23:46:34) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 23.0.0 (OpenSSL 1.1.1t  7 Feb 2023), cryptography 39.0.1, Platform Windows-10-10.0.19044-SP0
# 2023-05-17 13:22:30 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'web_crawling',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'web_crawling.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['web_crawling.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-05-17 13:22:30 [asyncio] DEBUG: Using selector: SelectSelector
# ...
